# %% [markdown]
# # Food Delivery Data Analysis – Hackathon Submission
#
# This notebook demonstrates basic loading and inspection of the final merged dataset used for the hackathon.

# %%
import pandas as pd

df = pd.read_csv('final_food_delivery_dataset.csv')
df.head()

# %%
df.shape

# %%
df.groupby('membership')['total_amount'].sum()
